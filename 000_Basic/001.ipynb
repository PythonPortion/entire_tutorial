# %%
a = 10
b = 20
c = 30
d = 40
sum = a + \
      b + \
      c + \
      d
print(sum)

# %%
a = 10
b = 10
print(id(a))
print(id(b))

# a = 11
# print(id(a))
# print(id(b))
# Out:
# 4313674872
# 4313674872

# %%
print(f"id_may:{id("May")}")
print(f"id_age:{id(25)}")
# Out:
# id_may:4337542288
# id_age:4343838296

# %%
month = "May"
age = 15
print(f"id_month:{id(month)}")
print(f"id_age:{id(age)}")
# Out:
# id_month:4337542288
# id_age:4343837976

# %% [markdown]
# the label is an identifier. it is usually called as a variable.
# A python variable is a symbolic name that is a reference or pointer to an objec.

# %%
type(month)
# Out:
# str

# %%
type(age)
# Out:
# int
