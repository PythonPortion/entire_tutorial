# %%
var = "3/4"
print(var)
# Out:
# 3/4

# %%
var = "\u00BE"
print(var)
# Out:
# ¾

# %%
ten = "10"
print(ten)

ten_ = "\u0031\u0030"
print(ten_)
# Out:
# 10
# 10

# %%
str = "Hello"
tobytes = str.encode('utf-8')
print(tobytes)
# Out:
# b'Hello'

# %%
str = tobytes.decode('utf-8')
print(str)
# Out:
# Hello
