# %%
def test(x,y,/,z,w):
    print(f"{x}")
    print(f"{y}")
    print(f"{z}")
    print(f"{w}")
    print(x + y + z + w)



# test(2,2,w=3,4)

# %%
test(1,2,3,4)
# Out:
# 1
# 2
# 3
# 4
# 10

# %%
test(1,2,3,4,5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 test(1,2,3,4,5)
#
# TypeError: test() takes 4 positional arguments but 5 were given

# %%
test(y=2,x=2,3,4)
# Out:
#   Cell In[15], line 1
#     test(y=2,x=2,3,4)
#                     ^
# SyntaxError: positional argument follows keyword argument

# %%
test(x = 2, y = 3,4,5)
# Out:
#   Cell In[17], line 1
#     test(x = 2, y = 3,4,5)
#                          ^
# SyntaxError: positional argument follows keyword argument

# %%
test(2, 3,w = 4,z = 5)
# Out:
# 2
# 3
# 5
# 4
# 14

# %%
# Out:
#   File <string>:3
#     print(arg1)
#                ^
# IndentationError: unindent does not match any outer indentation level

# %%
printinfo(10)

# %%
a = 10
b = 20

def add():
    print(globals())
    # global b

    globals()['b'] = a + b
    # b = a + b
    print(b)

add()
# Out:
# {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, '__loader__': None, '__spec__': None, '__builtin__': <module 'builtins' (built-in)>, '__builtins__': <module 'builtins' (built-in)>, '_ih': ['', 'def test(x,y,/,z,w):\n    print(x + y + z + w)\n\ntest(1,2,3,4)', 'def test(x,y,/,z,w):\n    print(f"{x}")\n    print(f"{y}")\n    print(f"{z}")\n    print(f"{w}")\n    print(x + y + z + w)\n\ntest(1,2,3,4)', 'def test(x,y,/,z,w):\n    print(f"{x}")\n    print(f"{y}")\n    print(f"{z}")\n    print(f"{w}")\n    print(x + y + z + w)\n\ntest(2,2,3,4)', 'def test(x,y,/,z,w):\n    print(f"{x}")\n    print(f"{y}")\n    print(f"{z}")\n    print(f"{w}")\n    print(x + y + z + w)\n\ntest(y=2,2,3,4)', 'def test(x,y,/,z,w):\n    print(f"{x}")\n    print(f"{y}")\n    print(f"{z}")\n    print(f"{w}")\n    print(x + y + z + w)\n\ntest(2,2,w=3,4)', 'def test(x,y,/,z,w):\n    print(f"{x}")\n    print(f"{y}")\n    print(f"{z}")\n    p
# ...
