# %%
def pack(*arg):
    print(*arg)

# li = [1,2,3,4]
li = 1,2,3,4
pack(li)
# Out:
# (1, 2, 3, 4)

# %%
def unpack(a,b,c):
    print(a,b,c)

li = [1,2,3]
unpack(*li)
# Out:
# 1 2 3

# %%
# tu = (1,2,3,4,5,6,7)
tu = [1,2,3,4,5,6,7]

x, *y, z = tu
print(x)
print(*y)
print(z)
# Out:
# 1
# 2 3 4 5 6
# 7
