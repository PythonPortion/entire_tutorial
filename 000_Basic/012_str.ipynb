# %%
s1 = "WORD"
l1 = list(s1)
print(l1)


l1.insert(2, "P")
print(l1)

s1 = "".join(l1)
print(s1)
# Out:
# ['W', 'O', 'R', 'D']
# ['W', 'O', 'P', 'R', 'D']
# WOPRD

# %%
import array as arr
s1 = "WORD"

sarr = arr.array('u', s1)
sarr.insert(2, 'L')
print(sarr)
s1 = sarr.tounicode()
print(s1)
# Out:
# array('u', 'WOLRD')
# WOLRD
# /var/folders/0s/dbyt0gw12s3fc73x51n5djfm0000gn/T/ipykernel_21052/1129753286.py:4: DeprecationWarning: The 'u' type code is deprecated and will be removed in Python 3.16
#   sarr = arr.array('u', s1)
