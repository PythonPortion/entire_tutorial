# %%
a = 10
print(a)
print(id(a))
print("---")

def add(a):
    a += 1
    print(a)
    print(id(a))
add(a)
# Out:
# 10
# 4314920056
# ---
# 11
# 4314920088

# %%
a = [10]
print(a)
print(id(a))
print("---")

def add(a):
    a[0]+=1
    print(a)
    print(id(a))

add(a)
# Out:
# [10]
# 4432639680
# ---
# [11]
# 4432639680
