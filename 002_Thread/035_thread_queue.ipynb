# %%
import threading
import queue

q = queue.Queue()

def worker():
    while True:
        item = q.get()
        print(f'Working on {item}')
        print(f'Finished {item}')
        q.task_done()

# Turn-on the worker thread.
threading.Thread(target=worker, daemon=True).start()

# Send thirty task requests to the worker.
for item in range(10):
    print(f'Putting {item} in the queue')
    q.put(item)

# Block until all tasks are done.
q.join()
print('All work completed')
# Out:
# Putting 0 in the queue
# Putting 1 in the queue
# Putting 2 in the queue
# Putting 3 in the queue
# Putting 4 in the queue
# Putting 5 in the queue
# Putting 6 in the queue
# Putting 7 in the queue
# Putting 8 in the queue
# Putting 9 in the queue
# Working on 0
# Finished 0
# Working on 1
# Finished 1
# Working on 2
# Finished 2
# Working on 3
# Finished 3
# Working on 4
# Finished 4
# Working on 5
# Finished 5
# Working on 6
# Finished 6
# Working on 7
# Finished 7
# Working on 8
# Finished 8
# Working on 9
# Finished 9
# All work completed
